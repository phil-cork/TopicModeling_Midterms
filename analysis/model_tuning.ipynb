# %%
import pandas as pd
import numpy as np

# Path hack
import os
# change directory from the current Analysis folder to the top level folder for easier navigation
os.chdir('../')
# confirm we're at top level folder
print(os.getcwd())

# note that the %load_ext autoreload line only needs to be be run once
# %load_ext autoreload
# Out:
# /Users/prcork/Georgetown/Fall2022/DS3/final_project

# %%
# %autoreload
from functions import text_analysis

# %%
df = pd.read_csv("data/reddit_output.csv")
# separate into each subreddit
dem = df.query("subreddit=='democrats'").copy()
con = df.query("subreddit=='conservative'").copy()

# %%
#plot and store minimum document frequency results for dems
dem_min_df = text_analysis.get_min_df(start=1, end=10, documents=dem.title)

# %%
# plot Perplexity for democrats subreddit with min_df of 6
dem_per = text_analysis.get_model_perplexity(documents=dem.title, min_df=6, start=1, end=30)

# %%
# determine min_df for conservative subreddit
con_min_df = text_analysis.get_min_df(start=1, end=10, documents=con.title)

# %%
# plot Perplexity for conservative subreddit data
con_per = text_analysis.get_model_perplexity(documents=con.title, min_df=9, start=1, end=50)

# %%
# does min_df changing affect Perplexity?
con_per = text_analysis.get_model_perplexity(documents=con.title, min_df=6, start=1, end=30)
